# %% [markdown]
# # Cuaderno de Notas de Métodos Numéricos
# ## Introducción al Curso
# ### Prof. Jorge I. Zuluaga

# %% [markdown]
# #### Ejecutarme siempre

# %% [markdown]
# A continuación descargamos en el espacio virtual de este cuaderno todos los archivos necesarios para que las notas del curso funcionen bien:

# %%
# !git clone https://github.com/JorgeZuluaga/NotasMetodosNumericos
# !ln -s NotasMetodosNumericos mn
# !make -C mn pull
# Out:
# fatal: destination path 'NotasMetodosNumericos' already exists and is not an empty directory.
# make: Entering directory '/content/NotasMetodosNumericos'
# git reset --hard HEAD
# HEAD is now at ae93474 Commit
# git pull origin master
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 5 (delta 0), pack-reused 0
# Unpacking objects: 100% (5/5), done.
# From https://github.com/JorgeZuluaga/NotasMetodosNumericos
#  * branch            master     -> FETCH_HEAD
#    ae93474..9a4157d  master     -> origin/master
# Updating ae93474..9a4157d
# Fast-forward
#  "MN-CuadernoNotas-Introducci\303\263n.ipynb" |   1 +
#  figuras/zuluaga-divulgacion.jpg              | Bin 0 -> 38551 bytes
#  2 files changed, 1 insertion(+)
#  create mode 100644 "MN-CuadernoNotas-Introducci\303\263n.ipynb"
#  create mode 100644 figuras/zuluaga-divulgacion.jpg
# make: Leaving directory '/content/NotasMetodosNumericos'

# %% [markdown]
# ## Un vistazo de la clase

# %% [markdown]
#   Qué veremos en esta clase:
#
#   - Presentaciones.
#   - ¿Qué son los métodos numéricos?.
#   - Fuentes de información.
#   - ¿Cómo evaluaremos el curso?.
#   - Herramientas de comunicación e interacción con el profesor.

# %% [markdown]
# ## Presentaciones

# %% [markdown]
# Mi nombre es Jorge I. Zuluaga, soy físico y tengo un doctorado en física de la Universidad de Antioquia.

# %% [markdown]
# Mis áreas de especialidad técnica son los métodos numéricos y computacionales aplicados en ciencias, la programación científica, y la computación de alto rendimiento.
#
# <center><img src="https://github.com/JorgeZuluaga/NotasMetodosNumericos/raw/master/figuras/ejemplo-computacion-cientifica.gif" width=400></br>Simulacion de la sombra proyectada por un exoplaneta</center>

# %% [markdown]
# Mis áreas de especialidad científica astrofísica, ciencias planetarias, exoplanetas, astrobiología.

# %% [markdown]
# Mi gran pasión (además de la investigación científica y la programación) es la divulgación científica.  Durante unos años realicé un programa para Telemedellín que se llamaba [Eso no tiene ciencia](https://www.youtube.com/watch?v=_e9t6Qdt8yo&list=PL2hl1l-cy3EJVCLCFSHnEPgV8e2klVMTQ)
#
# <center><img src="https://github.com/JorgeZuluaga/NotasMetodosNumericos/raw/master/figuras/zuluaga-divulgacion.jpg" width=400></center>
#
# También hago divulgación en redes sociales, [TikTok, @zuluagajorge](tiktok.com/@zuluagajorge), [Twitter, @zuluagajorge](https://twitter.com/zuluagajorge) e [Instagram](https://www.instagram.com/jorgeizuluagac/), aunque en estas dos últimas público especialmente cosas personales.

# %% [markdown]
# ## ¿Qué son los métodos numéricos?

# %% [markdown]
# ## Fuentes de información

# %% [markdown]
# ## ¿Cómo evaluaremos el curso?

# %% [markdown]
# ## Herramientas de comunicación e interacción con el profesor

# %% [markdown]
# -------
# *Esta historia continuará...*
